# %% [markdown]
# ## ZAYYED AKHMED ASSIDQIE
# ## FTDS 006
# ## MILESTONE 1

# %% [markdown]
# Context
#
# The growth of supermarkets in most populated cities are increasing and market competitions are also high. The dataset is one of the historical sales of supermarket company which has recorded in 3 different branches for 3 months data. Predictive data analytics methods are easy to apply with this dataset.
#
# Attribute information
#
# - Invoice id: Computer generated sales slip invoice identification number
# - Branch: Branch of supercenter (3 branches are available identified by A, B and C).
# - City: Location of supercenters
# - Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
# - Gender: Gender type of customer
# - Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
# - Unit price: Price of each product in dollar
# - Quantity: Number of products purchased by customer
# - Tax: 5percent tax fee for customer buying
# - Total: Total price including tax
# - Date: Date of purchase (Record available from January 2019 to March 2019)
# - Time: Purchase time (10am to 9pm)
# - Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
# - COGS: Cost of goods sold
# - Gross margin percentage: Gross margin percentage
# - Gross income: Gross income
# - Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import plotly.express as px

# %%
df = pd.read_csv("supermarket_sales.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.describe(include = object)
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
#
#             Date   Time  Payment
# count       1000   1000     1000
# unique        89    506        3
# top     2/7/2019  19:48  Ewallet
# freq          20      7      345

# %%
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df.drop(columns = ["Invoice ID", "Time"], inplace=True)

# %%
df.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date      Payment    cogs  \
# 0         7  26.1415  548.9715 2019-01-05      Ewallet  522.83
# 1         5   3.8200   80.2200 2019-03-08         Cash   76.40
# 2         7  16.2155  340.5255 2019-03-03  Credit card  324.31
# 3         8  23.2880  489.0480 2019-01-27      Ewallet  465.76
# 4         7  30.2085  634.3785 2019-02-08      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating
# 0                 4.761905       26.1415     9.1
# ...

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.head()
# Out:
#   Branch       City Customer_type  Gender            Product_line  Unit_price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax_5%     Total       Date      Payment    cogs  \
# 0         7  26.1415  548.9715 2019-01-05      Ewallet  522.83
# 1         5   3.8200   80.2200 2019-03-08         Cash   76.40
# 2         7  16.2155  340.5255 2019-03-03  Credit card  324.31
# 3         8  23.2880  489.0480 2019-01-27      Ewallet  465.76
# 4         7  30.2085  634.3785 2019-02-08      Ewallet  604.17
#
#    gross_margin_percentage  gross_income  Rating
# 0                 4.761905       26.1415     9.1
# ...

# %%
df.to_csv("C:\\Users\\ASUS\\Desktop\\Dash\\sales_clean.csv")

# %% [markdown]
# ## Central Tendency

# %%
mean = ['Unit_price','Quantity','Tax_5%','Total','cogs','gross_margin_percentage', "gross_income", "Rating"]
for i in mean:
    print ('Mean dari', i, "adalah",  round(np.mean(df[i]), 3))
# Out:
# Mean dari Unit_price adalah 55.672
# Mean dari Quantity adalah 5.51
# Mean dari Tax_5% adalah 15.379
# Mean dari Total adalah 322.967
# Mean dari cogs adalah 307.587
# Mean dari gross_margin_percentage adalah 4.762
# Mean dari gross_income adalah 15.379
# Mean dari Rating adalah 6.973

# %%
df.groupby("Product_line")["Unit_price"].mean()
# Out:
# Product_line
# Electronic accessories    53.551588
# Fashion accessories       57.153652
# Food and beverages        56.008851
# Health and beauty         54.854474
# Home and lifestyle        55.316937
# Sports and travel         56.993253
# Name: Unit_price, dtype: float64

# %%
median = ['Unit_price','Quantity','Tax_5%','Total','cogs','gross_margin_percentage', "gross_income", "Rating"]
for i in median:
    print ('Median dari', i, "adalah",  round(np.median(df[i]), 3))
# Out:
# Median dari Unit_price adalah 55.23
# Median dari Quantity adalah 5.0
# Median dari Tax_5% adalah 12.088
# Median dari Total adalah 253.848
# Median dari cogs adalah 241.76
# Median dari gross_margin_percentage adalah 4.762
# Median dari gross_income adalah 12.088
# Median dari Rating adalah 7.0

# %%
mode = ['Unit_price','Quantity','Tax_5%','Total','cogs','gross_margin_percentage', "gross_income", "Rating"]
for i in mode:
    print ('Modus dari', i, "adalah",  df[i].mode()[0])
# Out:
# Modus dari Unit_price adalah 83.77
# Modus dari Quantity adalah 10
# Modus dari Tax_5% adalah 4.154
# Modus dari Total adalah 87.234
# Modus dari cogs adalah 83.08
# Modus dari gross_margin_percentage adalah 4.761904762
# Modus dari gross_income adalah 4.154
# Modus dari Rating adalah 6.0

# %%
mode_cat = ["Branch", "City", "Customer_type", "Gender", "Product_line", "Payment"]
for i in mode_cat:
    print("Modus dari", i, "adalah", df[i].mode()[0])
# Out:
# Modus dari Branch adalah A
# Modus dari City adalah Yangon
# Modus dari Customer_type adalah Member
# Modus dari Gender adalah Female
# Modus dari Product_line adalah Fashion accessories
# Modus dari Payment adalah Ewallet

# %% [markdown]
# ## Data Exploration

# %%
plt.figure(figsize=(18,9))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
A = df["City"].value_counts()
A = pd.DataFrame(A)
A
# Out:
#            City
# Yangon      340
# Mandalay    332
# Naypyitaw   328

# %%
plt.figure(figsize=(16,7))
plt.bar(A.index, A['City'])
plt.xlabel("City")
plt.ylim(0, 400)
plt.annotate(f'{A.iloc[0,0]}',
             xy=('Yangon', A.loc['Yangon']), ha='center')
plt.annotate(f'{A.iloc[1,0]}',
             xy=('Mandalay', A.loc['Mandalay']), ha='center')
plt.annotate(f'{A.iloc[2,0]}',
             xy=('Naypyitaw', A.loc['Naypyitaw']), ha='center')
plt.title('Jumlah Pembelian di tiap Branch')
plt.show()

# %%
jan = df[df["Date"]<"2019-02-01"]

# %%
jan.head()
# Out:
#    Branch      City Customer_type  Gender       Product_line  Unit_price  \
# 0       A    Yangon        Member  Female  Health and beauty       74.69
# 3       A    Yangon        Member    Male  Health and beauty       58.22
# 8       A    Yangon        Member  Female  Health and beauty       36.26
# 15      B  Mandalay        Member  Female  Sports and travel       93.72
# 17      A    Yangon        Normal    Male  Sports and travel       72.61
#
#     Quantity   Tax_5%     Total       Date      Payment    cogs  \
# 0          7  26.1415  548.9715 2019-01-05      Ewallet  522.83
# 3          8  23.2880  489.0480 2019-01-27      Ewallet  465.76
# 8          2   3.6260   76.1460 2019-01-10  Credit card   72.52
# 15         6  28.1160  590.4360 2019-01-15         Cash  562.32
# 17         6  21.7830  457.4430 2019-01-01  Credit card  435.66
#
#     gross_margin_percentage  gross_income  Rating
# 0                  4.761905       26.1415     9.1
# ...

# %%
Rat = df.groupby("City")["Rating"].mean()
Rat=pd.DataFrame(Rat)
Rat
# Out:
#              Rating
# City
# Mandalay   6.818072
# Naypyitaw  7.072866
# Yangon     7.027059

# %%
B = df["Customer_type"].value_counts()
B = pd.DataFrame(B)
B
# Out:
#         Customer_type
# Member            501
# Normal            499

# %%
plt.figure(figsize=(16,7))
plt.bar(B.index, B['Customer_type'])
plt.xlabel("Customer Type")
plt.ylim(0, 600)
plt.annotate(f'{B.iloc[0,0]}',
             xy=('Member', B.loc['Member']), ha='center')
plt.annotate(f'{B.iloc[1,0]}',
             xy=('Normal', B.loc['Normal']), ha='center')
plt.title('persebaran Customer Type di Supermarket Vietnam')
plt.show()

# %%
B_label = list(B.index)
B_label
plt.figure(figsize=(10,5))
plt.pie(B['Customer_type'], labels=B_label, autopct='%.2f%%')
plt.title("Presentase Customer Type Supermarket")
plt.show()

# %%
C = df["Gender"].value_counts()
C = pd.DataFrame(C)
C
# Out:
#         Gender
# Female     501
# Male       499

# %%
C_label = list(C.index)
C_label
plt.figure(figsize=(10,5))
plt.pie(C['Gender'], labels=C_label, autopct='%.2f%%')
plt.title("Presentase Gender dari Customer")
plt.show()

# %%
Mem = df.groupby("Customer_type")["gross_income"].sum()
Mem = pd.DataFrame(Mem)
Mem
# Out:
#                gross_income
# Customer_type
# Member             7820.164
# Normal             7559.205

# %%
plt.figure(figsize=(20,10))
plt.bar(Mem.index, Mem['gross_income'])
plt.xlabel("Customer Type")
plt.ylim(0, 10000)
plt.title('Tipe Customer yang paling banyak memberikan Gross Income')
plt.show()

# %%
Mem_label = list(Mem.index)
Mem_label
plt.figure(figsize=(10,5))
plt.pie(Mem['gross_income'], labels=Mem_label, autopct='%.2f%%')
plt.title("Presentase Tipe Customer yang paling banyak memberikan Gross Income")
plt.show()

# %%
CC = df["Payment"].value_counts()
CC = pd.DataFrame(CC)
CC
# Out:
#              Payment
# Ewallet          345
# Cash             344
# Credit card      311

# %%
CC_label = list(CC.index)
CC_label
plt.figure(figsize=(10,5))
plt.pie(CC['Payment'], labels=CC_label, autopct='%.2f%%')
plt.title("Metode Pembayaran yang Paling Banyak Dipakai Customer")
plt.show()

# %%
df.groupby(["Customer_type", "Gender"])["Gender"].count()
# Out:
# Customer_type  Gender
# Member         Female    261
#                Male      240
# Normal         Female    240
#                Male      259
# Name: Gender, dtype: int64

# %%
df.Product_line.value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product_line, dtype: int64

# %%
sns.countplot(y = 'Product_line', data=df, order = df['Product_line'].value_counts().index )

# %%
D = df.groupby("Product_line")["Quantity"].sum()
D = pd.DataFrame(D).sort_values("Quantity", ascending=False)
D
# Out:
#                         Quantity
# Product_line
# Electronic accessories       971
# Food and beverages           952
# Sports and travel            920
# Home and lifestyle           911
# Fashion accessories          902
# Health and beauty            854

# %%
plt.figure(figsize=(20,10))
plt.bar(D.index, D['Quantity'])
plt.xlabel("Product Line")
plt.ylim(0, 1100)
plt.title('Produk yang Paling Banyak Terjual')
plt.show()

# %%
GI = df.groupby("City")["gross_income"].sum()
GI = pd.DataFrame(GI)
GI
# Out:
#            gross_income
# City
# Mandalay      5057.0320
# Naypyitaw     5265.1765
# Yangon        5057.1605

# %%
plt.figure(figsize=(20,10))
plt.bar(GI.index, GI['gross_income'])
plt.xlabel("City")
plt.ylim(0, 5500)
plt.title('Jumlah Gross Income Tiap Branch')
plt.show()

# %%
GIP = df.groupby("Product_line")["gross_income"].sum()
GIP = pd.DataFrame(GIP)
GIP
# Out:
#                         gross_income
# Product_line
# Electronic accessories       44.8785
# Fashion accessories          49.6500
# Food and beverages           49.2600
# Health and beauty            45.2500
# Home and lifestyle           48.7500
# Sports and travel            47.7200

# %%
plt.figure(figsize=(20,10))
plt.bar(GIP.index, GIP['gross_income'])
plt.xlabel("Product Line")
plt.ylim(0, 2700)
plt.title('Produk dengan Jumlah Gross Income terbesar')
plt.show()

# %%
Qual = df.groupby("Date")["Quantity"].sum()
Qual=pd.DataFrame(Qual)
Qual
# Out:
#             Quantity
# Date
# 2019-01-01        81
# 2019-01-02        48
# 2019-01-03        37
# 2019-01-04        32
# 2019-01-05        55
# ...              ...
# 2019-03-26        52
# 2019-03-27        45
# 2019-03-28        48
# 2019-03-29        54
# 2019-03-30        67
#
# [89 rows x 1 columns]

# %%
genderCount  = sns.lineplot(x=Qual.index,  y = 'Quantity',data =Qual).set_title("Product Sales per Date")

# %%
QQ = pd.DataFrame(df.groupby(df['Date'].dt.strftime('%B'))['Quantity'].sum())
QQ
# Out:
#           Quantity
# Date
# February      1654
# January       1965
# March         1891

# %%
QQQ = {'Date':['January', 'February', 'March'],
        'Quantity':[1965, 1654, 1891]}
 
QQQ = pd.DataFrame(QQQ)
QQQ
# Out:
#        Date  Quantity
# 0   January      1965
# 1  February      1654
# 2     March      1891

# %%
plt.figure(figsize=(20,6))
x = QQQ["Date"]
y = QQQ['Quantity']
plt.plot(x, y, 'Blue')
plt.title('Total Penjualan Tiap Bulan', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Penjualan')
plt.show()

# %%
EEE = df.groupby("Product_line")["gross_income"].mean()
EEE = pd.DataFrame(EEE)
EEE
# Out:
#                         gross_income
# Product_line
# Electronic accessories     15.220597
# Fashion accessories        14.528062
# Food and beverages         15.365310
# Health and beauty          15.411572
# Home and lifestyle         16.030331
# Sports and travel          15.812630

# %%
G = df.groupby("Date")["gross_income"].sum()
G = pd.DataFrame(G)
G
# Out:
#             gross_income
# Date
# 2019-01-01      225.9610
# 2019-01-02       92.6430
# 2019-01-03       98.9585
# 2019-01-04       77.3185
# 2019-01-05      168.4135
# ...                  ...
# 2019-03-26       93.4530
# 2019-03-27      138.2295
# 2019-03-28      106.1620
# 2019-03-29      191.5830
# 2019-03-30      213.6695
#
# [89 rows x 1 columns]

# %%
plt.figure(figsize=(20,10))
plt.bar(EEE.index, EEE['gross_income'])
plt.xlabel("Product Line")
plt.ylim(0, 20)
plt.title('Produk dengan Rata2 Total Harga Penjualan terbesar')
plt.show()

# %%
plt.figure(figsize=(20,6))
x = G.index
y = G['gross_income']
plt.plot(x, y, 'red')
plt.title('Total Gross Income', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %%
MTH = pd.DataFrame(df.groupby(df['Date'].dt.strftime('%B'))['gross_income'].sum())
MTH
# Out:
#           gross_income
# Date
# February      4629.494
# January       5537.708
# March         5212.167

# %%
plt.figure(figsize=(20,6))
x = MTH.index
y = MTH['gross_income']
plt.plot(x, y, 'Blue')
plt.title('Total Gross Income Tiap Bulan', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %%
dic = {'Date':['January', 'February', 'March'],
        'gross_income':[1925.4610,1568.3325,1771.3830]}
 
dic = pd.DataFrame(dic)
dic
# Out:
#        Date  gross_income
# 0   January     1925.4610
# 1  February     1568.3325
# 2     March     1771.3830

# %%
plt.figure(figsize=(20,6))
x = dic["Date"]
y = dic['gross_income']
plt.plot(x, y, 'Blue')
plt.title('Total Gross Income Tiap Bulan', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %%
# Rat = pd.DataFrame(df.groupby(df['Date'].dt.strftime('%B'))['Rating'].mean())
# Rat
# Out:
#             Rating
# Date
# February  7.071287
# January   7.017614
# March     6.840290

# %% [markdown]
# ## YANGON

# %%
df_Y = df[df["City"]=="Yangon"]

# %%
df_Y.head()
# Out:
#   Branch    City Customer_type  Gender            Product_line  Unit_price  \
# 0      A  Yangon        Member  Female       Health and beauty       74.69
# 2      A  Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A  Yangon        Member    Male       Health and beauty       58.22
# 4      A  Yangon        Normal    Male       Sports and travel       86.31
# 6      A  Yangon        Member  Female  Electronic accessories       68.84
#
#    Quantity   Tax_5%     Total       Date      Payment    cogs  \
# 0         7  26.1415  548.9715 2019-01-05      Ewallet  522.83
# 2         7  16.2155  340.5255 2019-03-03  Credit card  324.31
# 3         8  23.2880  489.0480 2019-01-27      Ewallet  465.76
# 4         7  30.2085  634.3785 2019-02-08      Ewallet  604.17
# 6         6  20.6520  433.6920 2019-02-25      Ewallet  413.04
#
#    gross_margin_percentage  gross_income  Rating
# 0                 4.761905       26.1415     9.1
# ...

# %%
df_Y_jan = df_Y[df_Y["Date"]<"2019-02-01"]

# %%
YY = df_Y["Customer_type"].value_counts()
YY = pd.DataFrame(YY)
YY
# Out:
#         Customer_type
# Normal            173
# Member            167

# %%
plt.figure(figsize=(16,7))
plt.bar(YY.index, YY['Customer_type'])
plt.xlabel("Customer Type")
plt.ylim(0, 200)
plt.annotate(f'{YY.iloc[0,0]}',
             xy=('Member', YY.loc['Member']), ha='center')
plt.annotate(f'{YY.iloc[1,0]}',
             xy=('Normal', YY.loc['Normal']), ha='center')
plt.title('Tipe Customer Supermarket Yangon')
plt.show()

# %%
YY_label = list(YY.index)
YY_label
plt.figure(figsize=(10,5))
plt.pie(YY['Customer_type'], labels=YY_label, autopct='%.2f%%')
plt.title("Presentase Customer Type Supermarket Yangon")
plt.show()

# %%
YYY = df_Y["Payment"].value_counts()
YYY = pd.DataFrame(YYY)
YYY
# Out:
#              Payment
# Ewallet          126
# Cash             110
# Credit card      104

# %%
YYY_label = list(YYY.index)
YYY_label
plt.figure(figsize=(10,5))
plt.pie(YYY['Payment'], labels=YYY_label, autopct='%.2f%%')
plt.title("Presentase Payment Supermarket Yangon")
plt.show()

# %%
QY = df_Y.groupby("Product_line")["Quantity"].sum()
QY = pd.DataFrame(QY).sort_values("Quantity")
QY
# Out:
#                         Quantity
# Product_line
# Health and beauty            257
# Fashion accessories          263
# Food and beverages           313
# Electronic accessories       322
# Sports and travel            333
# Home and lifestyle           371

# %%
plt.figure(figsize=(20,10))
plt.bar(QY.index, QY['Quantity'])
plt.xlabel("Product Line")
plt.ylim(0, 500)
plt.title('Produk yang Paling Banyak Terjual')
plt.show()

# %%
GIPY = df_Y.groupby("Product_line")["gross_income"].sum()
GIPY = pd.DataFrame(GIPY)
GIPY
# Out:
#                         gross_income
# Product_line
# Electronic accessories      872.2435
# Fashion accessories         777.7385
# Food and beverages          817.2905
# Health and beauty           599.8930
# Home and lifestyle         1067.4855
# Sports and travel           922.5095

# %%
plt.figure(figsize=(20,10))
plt.bar(GIPY.index, GIPY['gross_income'])
plt.xlabel("Product Line")
plt.ylim(0, 1200)
plt.title('Produk dengan Jumlah Gross Income terbesar')
plt.show()

# %%
GIY = df_Y.groupby("Date")["gross_income"].sum()
GIY = pd.DataFrame(GIY)
GIY
# Out:
#             gross_income
# Date
# 2019-01-01      112.9200
# 2019-01-02       14.6215
# 2019-01-03       44.6385
# 2019-01-04       23.0125
# 2019-01-05       96.4050
# ...                  ...
# 2019-03-26       56.5400
# 2019-03-27       50.5060
# 2019-03-28       78.7110
# 2019-03-29       46.5530
# 2019-03-30       62.8865
#
# [89 rows x 1 columns]

# %%
plt.figure(figsize=(20,6))
x = GIY.index
y = GIY['gross_income']
plt.plot(x, y, 'red')
plt.title('Total Gross Income', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %%
MTHQ = pd.DataFrame(df_Y.groupby(df_Y['Date'].dt.strftime('%B'))['Quantity'].sum())
MTHQ.sort_index(axis=0, inplace=True)
MTHQ
# Out:
#           Quantity
# Date
# February       493
# January        685
# March          681

# %%
QQQ = {'Date':['January', 'February', 'March'],
        'gross_income':[685,493,681]}
 
QQQ = pd.DataFrame(QQQ)
QQQ
# Out:
#        Date  gross_income
# 0   January           685
# 1  February           493
# 2     March           681

# %%
plt.figure(figsize=(20,6))
x = MTHY.index
y = MTHY['gross_income']
plt.plot(x, y, 'Blue')
plt.title('Total Gross Income Tiap Bulan', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %%
dic = {'Date':['January', 'February', 'March'],
        'gross_income':[1841.9585,1421.9105,1793.2915]}
 
dic = pd.DataFrame(dic)

# %%
dic
# Out:
#        Date  gross_income
# 0   January     1841.9585
# 1  February     1421.9105
# 2     March     1793.2915

# %%
plt.figure(figsize=(20,6))
x = dic["Date"]
y = dic['gross_income']
plt.plot(x, y, 'Blue')
plt.title('Total Gross Income Tiap Bulan', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %% [markdown]
# ## Mandalay

# %%
df_m = df[df["City"]=="Mandalay"]
df_m.head()
# Out:
#    Branch      City Customer_type  Gender            Product_line  Unit_price  \
# 9       B  Mandalay        Member  Female      Food and beverages       54.84
# 10      B  Mandalay        Member  Female     Fashion accessories       14.48
# 11      B  Mandalay        Member    Male  Electronic accessories       25.51
# 15      B  Mandalay        Member  Female       Sports and travel       93.72
# 19      B  Mandalay        Normal  Female      Home and lifestyle       40.30
#
#     Quantity  Tax_5%    Total       Date      Payment    cogs  \
# 9          3   8.226  172.746 2019-02-20  Credit card  164.52
# 10         4   2.896   60.816 2019-02-06      Ewallet   57.92
# 11         4   5.102  107.142 2019-03-09         Cash  102.04
# 15         6  28.116  590.436 2019-01-15         Cash  562.32
# 19         2   4.030   84.630 2019-03-11      Ewallet   80.60
#
#     gross_margin_percentage  gross_income  Rating
# 9                  4.761905         8.226     5.9
# ...

# %%
m = df_m["Customer_type"].value_counts()
m = pd.DataFrame(m)
m
# Out:
#         Customer_type
# Normal            167
# Member            165

# %%
plt.figure(figsize=(16,7))
plt.bar(m.index, m['Customer_type'])
plt.xlabel("Customer Type")
plt.ylim(0, 200)
plt.annotate(f'{m.iloc[0,0]}',
             xy=('Member', m.loc['Member']), ha='center')
plt.annotate(f'{m.iloc[1,0]}',
             xy=('Normal', m.loc['Normal']), ha='center')
plt.title('Tipe Customer Supermarket Mandalay')
plt.show()

# %%
m_label = list(m.index)
m_label
plt.figure(figsize=(10,5))
plt.pie(m['Customer_type'], labels=m_label, autopct='%.2f%%')
plt.title("Presentase Customer Type Supermarket Mandalay")
plt.show()

# %%
MM = df_m["Payment"].value_counts()
MM = pd.DataFrame(MM)
MM
# Out:
#              Payment
# Ewallet          113
# Cash             110
# Credit card      109

# %%
MM_label = list(MM.index)
MM_label
plt.figure(figsize=(10,5))
plt.pie(MM['Payment'], labels=MM_label, autopct='%.2f%%')
plt.title("Presentase Payment Supermarket Mandalay")
plt.show()

# %%
QM = df_m.groupby("Product_line")["Quantity"].sum()
QM = pd.DataFrame(QM).sort_values("Quantity")
QM
# Out:
#                         Quantity
# Product_line
# Food and beverages           270
# Home and lifestyle           295
# Fashion accessories          297
# Electronic accessories       316
# Health and beauty            320
# Sports and travel            322

# %%
plt.figure(figsize=(20,10))
plt.bar(QM.index, QM['Quantity'])
plt.xlabel("Product Line")
plt.ylim(0, 500)
plt.title('Produk yang Paling Banyak Terjual')
plt.show()

# %%
GIPM = df_m.groupby("Product_line")["gross_income"].sum()
GIPM = pd.DataFrame(GIPM)
GIPM
# Out:
#                         gross_income
# Product_line
# Electronic accessories      811.9735
# Fashion accessories         781.5865
# Food and beverages          724.5185
# Health and beauty           951.4600
# Home and lifestyle          835.6745
# Sports and travel           951.8190

# %%
plt.figure(figsize=(20,10))
plt.bar(GIPM.index, GIPM['gross_income'])
plt.xlabel("Product Line")
plt.ylim(0, 1200)
plt.title('Produk dengan Jumlah Gross Income terbesar')
plt.show()

# %%
GIM = df_m.groupby("Date")["gross_income"].sum()
GIM = pd.DataFrame(GIM)
GIM
# Out:
#             gross_income
# Date
# 2019-01-01       73.1760
# 2019-01-02       55.3715
# 2019-01-03       48.4140
# 2019-01-04       24.3135
# 2019-01-05       23.1790
# ...                  ...
# 2019-03-26       14.3430
# 2019-03-27       42.8045
# 2019-03-28        4.5555
# 2019-03-29       98.0920
# 2019-03-30       82.1170
#
# [86 rows x 1 columns]

# %%
plt.figure(figsize=(20,6))
x = GIM.index
y = GIM['gross_income']
plt.plot(x, y, 'red')
plt.title('Total Gross Income', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %%
MTHMQ = pd.DataFrame(df_m.groupby(df_m['Date'].dt.strftime('%B'))['Quantity'].sum())
MTHMQ
# Out:
#           Quantity
# Date
# February       624
# January        600
# March          596

# %%
MTHM = pd.DataFrame(df_m.groupby(df_m['Date'].dt.strftime('%B'))['gross_income'].sum())
MTHM
# Out:
#           gross_income
# Date
# February     1639.2510
# January      1770.2885
# March        1647.4925

# %%
plt.figure(figsize=(20,6))
x = MTHM.index
y = MTHM['gross_income']
plt.plot(x, y, 'Blue')
plt.title('Total Gross Income Tiap Bulan', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %%
dic = {'Date':['January', 'February', 'March'],
        'gross_income':[1770.2885,1639.2510,1647.4925]}
 
dic = pd.DataFrame(dic)
dic
# Out:
#        Date  gross_income
# 0   January     1770.2885
# 1  February     1639.2510
# 2     March     1647.4925

# %%
plt.figure(figsize=(20,6))
x = dic["Date"]
y = dic['gross_income']
plt.plot(x, y, 'Blue')
plt.title('Total Gross Income Tiap Bulan', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %% [markdown]
# ## Naypyitaw

# %%
df_N = df[df["City"]=="Naypyitaw"]
df_N.head()
# Out:
#    Branch       City Customer_type  Gender            Product_line  \
# 1       C  Naypyitaw        Normal  Female  Electronic accessories
# 5       C  Naypyitaw        Normal    Male  Electronic accessories
# 7       C  Naypyitaw        Normal  Female      Home and lifestyle
# 20      C  Naypyitaw        Member    Male  Electronic accessories
# 34      C  Naypyitaw        Member  Female      Food and beverages
#
#     Unit_price  Quantity   Tax_5%     Total       Date  Payment    cogs  \
# 1        15.28         5   3.8200   80.2200 2019-03-08     Cash   76.40
# 5        85.39         7  29.8865  627.6165 2019-03-25  Ewallet  597.73
# 7        73.56        10  36.7800  772.3800 2019-02-24  Ewallet  735.60
# 20       86.04         5  21.5100  451.7100 2019-02-25  Ewallet  430.20
# 34       99.42         4  19.8840  417.5640 2019-02-06  Ewallet  397.68
#
#     gross_margin_percentage  gross_income  Rating
# 1                  4.761905        3.8200     9.6
# ...

# %%
N = df_N["Customer_type"].value_counts()
N = pd.DataFrame(N)
N
# Out:
#         Customer_type
# Member            169
# Normal            159

# %%
plt.figure(figsize=(16,7))
plt.bar(N.index, N['Customer_type'])
plt.xlabel("Customer Type")
plt.ylim(0, 200)
plt.annotate(f'{N.iloc[0,0]}',
             xy=('Member', N.loc['Member']), ha='center')
plt.annotate(f'{N.iloc[1,0]}',
             xy=('Normal', N.loc['Normal']), ha='center')
plt.title('Tipe Customer Supermarket Mandalay')
plt.show()

# %%
N_label = list(N.index)
N_label
plt.figure(figsize=(10,5))
plt.pie(N['Customer_type'], labels=N_label, autopct='%.2f%%')
plt.title("Presentase Customer Type Supermarket Naypyitaw")
plt.show()

# %%
NN = df_N["Payment"].value_counts()
NN = pd.DataFrame(NN)
NN
# Out:
#              Payment
# Cash             124
# Ewallet          106
# Credit card       98

# %%
NN_label = list(NN.index)
NN_label
plt.figure(figsize=(10,5))
plt.pie(NN['Payment'], labels=NN_label, autopct='%.2f%%')
plt.title("Presentase Payment Supermarket Mandalay")
plt.show()

# %%
QN = df_N.groupby("Product_line")["Quantity"].sum()
QN = pd.DataFrame(QN).sort_values("Quantity")
QN
# Out:
#                         Quantity
# Product_line
# Home and lifestyle           245
# Sports and travel            265
# Health and beauty            277
# Electronic accessories       333
# Fashion accessories          342
# Food and beverages           369

# %%
plt.figure(figsize=(20,10))
plt.bar(QN.index, QN['Quantity'])
plt.xlabel("Product Line")
plt.ylim(0, 500)
plt.title('Produk yang Paling Banyak Terjual')
plt.show()

# %%
GIPN = df_N.groupby("Product_line")["gross_income"].sum()
GIPN = pd.DataFrame(GIPN)
GIPN
# Out:
#                         gross_income
# Product_line
# Electronic accessories      903.2845
# Fashion accessories        1026.6700
# Food and beverages         1131.7550
# Health and beauty           791.2060
# Home and lifestyle          661.6930
# Sports and travel           750.5680

# %%
plt.figure(figsize=(20,10))
plt.bar(GIPN.index, GIPN['gross_income'])
plt.xlabel("Product Line")
plt.ylim(0, 1200)
plt.title('Produk dengan Jumlah Gross Income terbesar')
plt.show()

# %%
GIN = df_N.groupby("Date")["gross_income"].sum()
GIN = pd.DataFrame(GIN)
GIN
# Out:
#             gross_income
# Date
# 2019-01-01       39.8650
# 2019-01-02       22.6500
# 2019-01-03        5.9060
# 2019-01-04       29.9925
# 2019-01-05       48.8295
# ...                  ...
# 2019-03-26       22.5700
# 2019-03-27       44.9190
# 2019-03-28       22.8955
# 2019-03-29       46.9380
# 2019-03-30       68.6660
#
# [88 rows x 1 columns]

# %%
plt.figure(figsize=(20,6))
x = GIN.index
y = GIN['gross_income']
plt.plot(x, y, 'red')
plt.title('Total Gross Income', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %%
MTHNQ = pd.DataFrame(df_N.groupby(df_N['Date'].dt.strftime('%B'))['Quantity'].sum())
MTHNQ
# Out:
#           Quantity
# Date
# February       537
# January        680
# March          614

# %%
MTHN = pd.DataFrame(df_N.groupby(df_N['Date'].dt.strftime('%B'))['gross_income'].sum())
MTHN
# Out:
#           gross_income
# Date
# February     1568.3325
# January      1925.4610
# March        1771.3830

# %%
plt.figure(figsize=(20,6))
x = MTHN.index
y = MTHN['gross_income']
plt.plot(x, y, 'Blue')
plt.title('Total Gross Income Tiap Bulan', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %%
dic = {'Date':['January', 'February', 'March'],
        'gross_income':[1925.4610,1568.3325,1771.3830]}
 
dic = pd.DataFrame(dic)
dic
# Out:
#        Date  gross_income
# 0   January     1925.4610
# 1  February     1568.3325
# 2     March     1771.3830

# %%
plt.figure(figsize=(20,6))
x = dic["Date"]
y = dic['gross_income']
plt.plot(x, y, 'Blue')
plt.title('Total Gross Income Tiap Bulan', size=20)
plt.xlabel('Daily')
plt.ylabel('Total Gross Income')
plt.show()

# %% [markdown]
# ## Hypotesis Testing

# %% [markdown]
# Hipotesis testing ini bertunjuan untuk menentukan apakah rata rata dari gross income dari tiap branch memiliki perbedaan yang signifikan apa tidak dengan menggunakan One Way Anova dengan membandingkan 3 variable

# %% [markdown]
# H0: μ_yangon = μ_mandalay = μ_naypyitaw
#
# H1: μ_yangon != μ_mandalay != μ_naypyitaw

# %%
sns.histplot(df[df['City'] == 'Yangon']['gross_income'], color='red', kde=True, label='Gross Income Yangon')
sns.histplot(df[df['City'] == 'Mandalay']['gross_income'], color='green', kde=True, label='Gross Income Mandalay')
sns.histplot(df[df['City'] == 'Naypyitaw']['gross_income'], color='blue', kde=True, label='Gross Income Naypyitaw')
plt.legend()
plt.show()

# %%
Yan = df[df["City"]=="Yangon"][["City","gross_income"]]
Man = df[df["City"]=="Mandalay"][["City","gross_income"]]
Nay = df[df["City"]=="Naypyitaw"][["City","gross_income"]]

# %%
Yan
# Out:
#        City  gross_income
# 0    Yangon       26.1415
# 2    Yangon       16.2155
# 3    Yangon       23.2880
# 4    Yangon       30.2085
# 6    Yangon       20.6520
# ..      ...           ...
# 990  Yangon       14.1400
# 992  Yangon        5.8030
# 997  Yangon        1.5920
# 998  Yangon        3.2910
# 999  Yangon       30.9190
#
# [340 rows x 2 columns]

# %%
Man
# Out:
#          City  gross_income
# 9    Mandalay         8.226
# 10   Mandalay         2.896
# 11   Mandalay         5.102
# 15   Mandalay        28.116
# 19   Mandalay         4.030
# ..        ...           ...
# 987  Mandalay        24.800
# 989  Mandalay        30.148
# 991  Mandalay        38.300
# 993  Mandalay         8.745
# 996  Mandalay        48.690
#
# [332 rows x 2 columns]

# %%
Nay
# Out:
#           City  gross_income
# 1    Naypyitaw        3.8200
# 5    Naypyitaw       29.8865
# 7    Naypyitaw       36.7800
# 20   Naypyitaw       21.5100
# 34   Naypyitaw       19.8840
# ..         ...           ...
# 983  Naypyitaw       34.9860
# 984  Naypyitaw       33.7295
# 988  Naypyitaw       41.1700
# 994  Naypyitaw        3.0475
# 995  Naypyitaw        2.0175
#
# [328 rows x 2 columns]

# %%
print("Rata rata Gross Income Yangon", np.mean(Yan)[0])
print("Rata rata Gross Income Mandalay", np.mean(Man)[0])
print("Rata rata Gross Income Naypyitaw", np.mean(Nay)[0])
# Out:
# Rata rata Gross Income Yangon 14.87400147058824
# Rata rata Gross Income Mandalay 15.232024096385551
# Rata rata Gross Income Naypyitaw 16.05236737804879
# D:\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3332: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
f_stat,p_value = stats.f_oneway(Yan["gross_income"], Man["gross_income"], Nay["gross_income"])
print('P-value:',p_value)
# Out:
# P-value: 0.413210174367147

# %% [markdown]
# ### KESIMPULAN

# %% [markdown]
# Hasil p value dari testing One Way ANOVA ini berkisar 0.413210174367147 yang berarti nilai p value lebih besar dari nilai Confidence intervalnya yaitu 0.05 ini menandakan H0 diterima yang berarti rata rata penjualan tiap branch Supermarket ini tidak mempunyai perbedaan yang signifikan atau cenderung sama, ini dapat dilihat dari nilai rata2 gross income dari tiap branch dimana yangon 14.87400147058824, Mandalay 15.232024096385551 dan Naypyitaw 16.05236737804879

# %%
# pd.DataFrame(df.groupby(["Date", "Product_line"])["gross_income"].sum())
# Out:
#                                    gross_income
# Date       Product_line
# 2019-01-01 Electronic accessories       65.8450
#            Fashion accessories          29.5830
#            Food and beverages           50.7630
#            Health and beauty             6.2870
#            Home and lifestyle           19.0360
# ...                                         ...
# 2019-03-30 Fashion accessories           4.0720
#            Food and beverages           38.3480
#            Health and beauty            93.8400
#            Home and lifestyle           10.3260
#            Sports and travel            36.4505
#
# [454 rows x 1 columns]

# %%
# ABC = pd.DataFrame(df.groupby([df['Date'].dt.strftime('%B'), df["Product_line"]])['gross_income'].sum())
# ABC
# Out:
#                                  gross_income
# Date     Product_line
# February Electronic accessories      826.8050
#          Fashion accessories         905.2315
#          Food and beverages          952.3980
#          Health and beauty           695.3455
#          Home and lifestyle          592.1135
#          Sports and travel           657.6005
# January  Electronic accessories      896.7280
#          Fashion accessories         921.1960
#          Food and beverages          931.9300
#          Health and beauty           780.1510
#          Home and lifestyle          975.9400
#          Sports and travel          1031.7630
# March    Electronic accessories      863.9685
#          Fashion accessories         759.5675
#          Food and beverages          789.2360
#          Health and beauty           867.0625
#          Home and lifestyle          996.7995
#          Sports and travel           935.5330

# %%
# A = df[(df['Date']< "2019-03-01") & (df['Date'] > "2019-01-31")]
# A["Date"].unique()
# Out:
# array(['2019-02-08T00:00:00.000000000', '2019-02-25T00:00:00.000000000',
#        '2019-02-24T00:00:00.000000000', '2019-02-20T00:00:00.000000000',
#        '2019-02-06T00:00:00.000000000', '2019-02-12T00:00:00.000000000',
#        '2019-02-07T00:00:00.000000000', '2019-02-17T00:00:00.000000000',
#        '2019-02-02T00:00:00.000000000', '2019-02-27T00:00:00.000000000',
#        '2019-02-10T00:00:00.000000000', '2019-02-03T00:00:00.000000000',
#        '2019-02-28T00:00:00.000000000', '2019-02-15T00:00:00.000000000',
#        '2019-02-14T00:00:00.000000000', '2019-02-11T00:00:00.000000000',
#        '2019-02-23T00:00:00.000000000', '2019-02-09T00:00:00.000000000',
#        '2019-02-01T00:00:00.000000000', '2019-02-05T00:00:00.000000000',
#        '2019-02-18T00:00:00.000000000', '2019-02-16T00:00:00.000000000',
#        '2019-02-22T00:00:00.000000000', '2019-02-13T00:00:00.000000000',
#        '2019-02-21T00:00:00.000000000', '2019-02-26T00:00:00.000000000',
# ...
